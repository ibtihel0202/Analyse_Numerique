# %% [markdown]
# <img src="tpan1.png">

# %% [markdown]
# *****

# %% [markdown]
# ## Exercice 1:<h2>
# >On considère le polynôme $p(x) = (x - 1)^6$.
# >
# >En développant on
# >peut écrire ce même polynôme sous la forme
# >$f(x) = x^6 - 6x^5 + 15x^4 - 20x^3 + 15x^2 - 6x + 1.$
# >
# >1) Avec Matlab évaluer $p(x)$ et $f(x)$ pour $x$ allant de $.998$ à
# >$1.002$ en choisissant des pas de $.0001$.
# >
# >2) Faire un graphique de $f(x)$ et $p(x)$. Commenter.

# %% [markdown]
# ### Correction exercice 1
# ## **1)**
# *Avec Matlab évaluer  𝑝(𝑥)  et  𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001 .*

# %%
def horner(a,x):
    n = len(a)
    result = a[1]
    for i in range(2,n):
        result = result * x + a[i]
        return result

# %%
def p(x):
    return (x-1)**6

# %%
def f(x):
    return x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1

# %%
p(0.998)
# Out:
# 6.400000000000034e-17

# %%
f(0.998)
# Out:
# 1.7763568394002505e-15

# %%
T=[1, -6, 15, -20, 15, -6, 1]
print("T= " , T)
print('-------- p(i) ---------')
tt=[0.998,0.001,1.002]
for i in tt :
 print("ans=" ,p(i))
print('-------- f(i) ---------')
tt=[0.998,0.001,1.002]
for i in tt :
 print("ans=" ,f(i))
print('-------- horner ---------')
tt=[0.998,0.001,1.002]
for i in tt :
 print("ans=" ,horner(T,i))
# Out:
# T=  [1, -6, 15, -20, 15, -6, 1]
# -------- p(i) ---------
# ans= 6.400000000000034e-17
# ans= 0.994014980014994
# ans= 6.400000000000034e-17
# -------- f(i) ---------
# ans= 1.7763568394002505e-15
# ans= 0.994014980014994
# ans= 1.7763568394002505e-15
# -------- horner ---------
# ans= 9.012
# ans= 14.994
# ans= 8.988

# %% [markdown]
# ## **2)**
# *Faire un graphique de  𝑓(𝑥)  et  𝑝(𝑥) . Commenter.*
#
# **Représentation Graphique de p(x)**

# %%
import matplotlib.pyplot as plt
import numpy as np
a1=np.arange(0.998,1.002,0.0001)
t="solution dans [0.998:0.0001:1.002]"
h=t.title()
print(h)
plt.xlabel("x")
plt.ylabel("p(x)")
plt.grid(True)
plt.plot(a1,p(a1))
# Out:
# Solution Dans [0.998:0.0001:1.002]

# %% [markdown]
# **Représentation Graphique de f(x)**

# %%
import matplotlib.pyplot as plt
import numpy as np
a2=np.arange(0.998,1.002,0.0001)
t="solution dans [0.998:0.0001:1.002]"
h=t.title()
print(h)
plt.xlabel("x")
plt.ylabel("p(x)")
plt.grid(True)
plt.plot(a2,f(a2),color='r')
plt.plot(a1,p(a1),'*')
plt.show()
# Out:
# Solution Dans [0.998:0.0001:1.002]

# %% [markdown]
# # EXERCICE 2:
#
# >On considère l'équation : $$ f(x)=x^3+x^2-3x-3=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[-2;2]$, puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
# >
# >2) Utiliser un programme `dicho.m` qui permettra de trouver les solutions de l'équation $f(x)=0$ avec $eps=0.001$.
# >
# >3) Modifier le programme `dicho.m` pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près.

# %% [markdown]
# ### Correction exercice 2

# %% [markdown]
# ## **1)**
# *Dessiner la courbe de  𝑓  dans l'intervalle  [−2;2] , puis trouver des intervalles convenables pour appliquer la méthode de >bisection.*

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# # Daprés le graph de $f$ il existe 3 solutions :
# - $\alpha_1 \in ]-2;-1.5[$
# - $\alpha_2 \in ]-1.5;-0.5[$
# - $\alpha_3 \in ]1.5;2[$

# %% [markdown]
# ## **2)**
# *Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation  𝑓(𝑥)=0  avec  𝑒𝑝𝑠=0.001 .*

# %%
import matplotlib.pyplot as plt
import numpy as np
def dicho(a,b,f,n):
 m =( a + b )/2
 err = abs(b - a)
    while err> n:
        if f(m) == 0:
            break
            if f(a) * f(m)<0:
                b = m
            else:
                a = m
                m = (a + b) / 2
                err = abs(b - a)
                x = m
# Out:
#   File "<ipython-input-58-a34f12e7fafc>", line 6
#     while err> n:
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# **3)**

# %%
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# # EXERCICE 3:
# >On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
# >
# >2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
# >
# >a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
# >
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >
# >3) Ecrire puis appliquer  une fonction Matlab que l'on appellera  `pointfixe.m` aux trois schémas précédents en prenant >`x0=1.5;eps=0.001`.
# >
# >4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?
# >

# %% [markdown]
# # Correction exercice 3
# **1)**
#
# *Dessiner la courbe de  𝑓  dans l'intervalle  [1;2] , puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).*

# %%
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# **2)**
#
# *Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:*
#
# *a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.*

# %% [markdown]
# ### *Calcul symbolique de la dérivée*

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# #### *Que pouvez vous conclure à propos des convergences de g1*

# %% [markdown]
# On peut dire que la fonction g1 converge

# %% [markdown]
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# Et d'aprés le théoréme de convergence de la méthode du point fixe on a:
# Si |g
# 0
# (α)| < 1, alors la méthode de point fixe converge localement
#
# Donc la fonction g2 converge

# %% [markdown]
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# on a :
#  Si |g
# 0
# (l)| > 1, la m´ethode de point fixe (la suite (xn) d´efinie par xn+1 = g(xn)) diverge pour
# tout choix de x0 6= α et x0 ∈ [a, b].

# %% [markdown]
# Donc la fonction g3 diverge

# %% [markdown]
# **3)**
#
# Ecrire puis appliquer une fonction Matlab que l'on appellera pointfixe.m aux trois schémas précédents en prenant >x0=1.5;eps=0.001.

# %%
f=lambda x:x**3+4*x**2-10
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x:sqrt(10./(x+4))
g3=lambda x:x-x**3-4*x**2+10
def [x,erreur,niter]=pointfixe(g, x0, eps, nmax):
    zero = x0
    for niter in mslice[1:nmax]:
        x = zero    #
        zero = g(x)    #
        erreur = abs(zero - x)
        if erreur < eps:
            return
        end
    end
    disp(mstring('pas de convergence avec le nombre d\'iteration indique'))
end
# Out:
#   File "<ipython-input-27-20a8417abac8>", line 5
#     def [x,erreur,niter]=pointfixe(g, x0, eps, nmax):
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# # EXERCICE 4:
# >1) On considère la fonction $f(x)=e^{-x}-x$. Ecrire puis appliquer  une fonction Matlab que l'on appellera `newton.m` à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ .
# >
# >2) Montrer que l'équation $f(x)=0$ admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de $x0=1$.

# %% [markdown]
# # Correction exercice 4
# **1)**

# %% [markdown]
# *On considère la fonction  𝑓(𝑥)=𝑒−𝑥−𝑥 . Ecrire puis appliquer une fonction Matlab que l'on appellera newton.m à la >fonction  𝑓 , en prenant  𝑥0=0 ,  𝑒𝑝𝑠=0.001  .*

# %%
def newtonn(a, eps):
    x1= a
    x2= x1-f(x1)/fprime(x1)
    while abs(x1 - x2) > eps:
        x1 = x2
        x2 = x1 - f(x1) / fprime(x1)
    return  x2

# %%
from sympy import *
import numpy as np 
import matplotlib.pyplot as plt
f= lambda x:exp(-x)-x
fprime = lambda x:-exp(-x)-1
t=np.linspace(0,1,100)
plt.plot(t, f(t),'r')
plt.grid(True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1311     try:
# -> 1312         rf = evalf_table[x.func]
#    1313         r = rf(x, prec, options)
#
# KeyError: <class 'sympy.tensor.array.dense_ndim_array.ImmutableDenseNDimArray'>
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-52-c91ff9541f5d> in <module>
#       5 fprime = lambda x:-exp(-x)-1
#       6 t=np.linspace(0,1,100)
# ----> 7 plt.plot(t, f(t),'r')
#       8 plt.grid(True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2759 @docstring.copy(Axes.plot)
#    2760 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2761     return gca().plot(
#    2762         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
#    2763         is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
# -> 1649             self.add_line(line)
#    1650         self._request_autoscale_view(scalex=scalex, scaley=scaley)
#    1651         return lines
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in add_line(self, line)
#    1848             line.set_clip_path(self.patch)
#    1849
# -> 1850         self._update_line_limits(line)
#    1851         if not line.get_label():
#    1852             line.set_label('_line%d' % len(self.lines))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _update_line_limits(self, line)
#    1870         Figures out the data limit of the given line, updating self.dataLim.
#    1871         """
# -> 1872         path = line.get_path()
#    1873         if path.vertices.size == 0:
#    1874             return
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in get_path(self)
#    1025         """
#    1026         if self._invalidy or self._invalidx:
# -> 1027             self.recache()
#    1028         return self._path
#    1029
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     673         if always or self._invalidy:
#     674             yconv = self.convert_yunits(self._yorig)
# --> 675             y = _to_unmasked_float_array(yconv).ravel()
#     676         else:
#     677             y = self._y
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in _to_unmasked_float_array(x)
#    1315         return np.ma.asarray(x, float).filled(np.nan)
#    1316     else:
# -> 1317         return np.asarray(x, float)
#    1318
#    1319
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\expr.py in __float__(self)
#     320         # to fail, and if it is we still need to check that it evalf'ed to
#     321         # a number.
# --> 322         result = self.evalf()
#     323         if result.is_Number:
#     324             return float(result)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(self, n, subs, maxn, chop, strict, quad, verbose)
#    1459             options['quad'] = quad
#    1460         try:
# -> 1461             result = evalf(self, prec + 4, options)
#    1462         except NotImplementedError:
#    1463             # Fall back to the ordinary evalf
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1311     try:
#    1312         rf = evalf_table[x.func]
# -> 1313         r = rf(x, prec, options)
#    1314     except KeyError:
#    1315         # Fall back to ordinary evalf if possible
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\evalf.py in <lambda>(x, prec, options)
#    1279         NaN: lambda x, prec, options: (fnan, None, prec, None),
#    1280
# -> 1281         exp: lambda x, prec, options: evalf_pow(
#    1282             Pow(S.Exp1, x.args[0], evaluate=False), prec, options),
#    1283
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\evalf.py in evalf_pow(v, prec, options)
#     722     # This determines the working precision that must be used
#     723     prec += 10
# --> 724     yre, yim, _, _ = evalf(exp, prec, options)
#     725     # Special cases: x**0
#     726     if not (yre or yim):
#
# C:\ProgramData\Anaconda3\lib\site-packages\sympy\core\evalf.py in evalf(x, prec, options)
#    1316         if 'subs' in options:
#    1317             x = x.subs(evalf_subs(prec, options['subs']))
# -> 1318         xe = x._eval_evalf(prec)
#    1319         if xe is None:
#    1320             raise NotImplementedError
#
# AttributeError: 'ImmutableDenseNDimArray' object has no attribute '_eval_evalf'

# %%
sol = newtonn(0, 0.001)
print(sol)
# Out:
# -(-1/2 + (-1/2 + exp(-1/2))/(-1 - exp(-1/2)) + exp(-1/2 + (-1/2 + exp(-1/2))/(-1 - exp(-1/2))))/(-1 - exp(-1/2 + (-1/2 + exp(-1/2))/(-1 - exp(-1/2)))) - (-1/2 + exp(-1/2))/(-1 - exp(-1/2)) + 1/2

# %% [markdown]
# **2)**

# %%
sol=newtonn(1,0.001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-1a7cbe3bcf83> in <module>
# ----> 1 sol=newtonn(1,0.001)
#
# <ipython-input-28-0f7202a5f87d> in newtonn(a, eps)
#       6         x1 = x2
#       7         x2 = x1 - f(x1) / fprime(x1)
# ----> 8     end
#       9     sol = x2
#
# NameError: name 'end' is not defined
