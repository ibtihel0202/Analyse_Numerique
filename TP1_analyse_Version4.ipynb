# %% [markdown]
# <img src="tpan1.png">

# %% [markdown]
# *****

# %% [markdown]
# ## Exercice 1:<h2>
# >On considère le polynôme $p(x) = (x - 1)^6$.
# >
# >En développant on
# >peut écrire ce même polynôme sous la forme
# >$f(x) = x^6 - 6x^5 + 15x^4 - 20x^3 + 15x^2 - 6x + 1.$
# >
# >1) Avec Matlab évaluer $p(x)$ et $f(x)$ pour $x$ allant de $.998$ à
# >$1.002$ en choisissant des pas de $.0001$.
# >
# >2) Faire un graphique de $f(x)$ et $p(x)$. Commenter.

# %% [markdown]
# ### Correction exercice 1
# ## **1)**
# *Avec Matlab évaluer  𝑝(𝑥)  et  𝑓(𝑥)  pour  𝑥  allant de  .998  à  1.002  en choisissant des pas de  .0001 .*

# %%
def horner(a,x):
    n = len(a)
    result = a[1]
    for i in range(2,n):
        result = result * x + a[i]
        return result

# %%
def p(x):
    return (x-1)**6

# %%
def f(x):
    return x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1

# %%
p(0.998)
# Out:
# 6.400000000000034e-17

# %%
f(0.998)
# Out:
# 1.7763568394002505e-15

# %%
T=[1, -6, 15, -20, 15, -6, 1]
print("T= " , T)
print('-------- p(i) ---------')
tt=[0.998,0.001,1.002]
for i in tt :
 print("ans=" ,p(i))
print('-------- f(i) ---------')
tt=[0.998,0.001,1.002]
for i in tt :
 print("ans=" ,f(i))
print('-------- horner ---------')
tt=[0.998,0.001,1.002]
for i in tt :
 print("ans=" ,horner(T,i))
# Out:
# T=  [1, -6, 15, -20, 15, -6, 1]
# -------- p(i) ---------
# ans= 6.400000000000034e-17
# ans= 0.994014980014994
# ans= 6.400000000000034e-17
# -------- f(i) ---------
# ans= 1.7763568394002505e-15
# ans= 0.994014980014994
# ans= 1.7763568394002505e-15
# -------- horner ---------
# ans= 9.012
# ans= 14.994
# ans= 8.988

# %% [markdown]
# ## **2)**
# *Faire un graphique de  𝑓(𝑥)  et  𝑝(𝑥) . Commenter.*
#
# **Représentation Graphique de p(x)**

# %%
import matplotlib.pyplot as plt
import numpy as np
a1=np.arange(0.998,1.002,0.0001)
t="solution dans [0.998:0.0001:1.002]"
h=t.title()
print(h)
plt.xlabel("x")
plt.ylabel("p(x)")
plt.grid(True)
plt.plot(a1,p(a1))
# Out:
# Solution Dans [0.998:0.0001:1.002]

# %% [markdown]
# **Représentation Graphique de f(x)**

# %%
import matplotlib.pyplot as plt
import numpy as np
a2=np.arange(0.998,1.002,0.0001)
t="solution dans [0.998:0.0001:1.002]"
h=t.title()
print(h)
plt.xlabel("x")
plt.ylabel("p(x)")
plt.grid(True)
plt.plot(a2,f(a2),color='r')
plt.plot(a1,p(a1),'*')
plt.show()
# Out:
# Solution Dans [0.998:0.0001:1.002]

# %% [markdown]
# # EXERCICE 2:
#
# >On considère l'équation : $$ f(x)=x^3+x^2-3x-3=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[-2;2]$, puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
# >
# >2) Utiliser un programme `dicho.m` qui permettra de trouver les solutions de l'équation $f(x)=0$ avec $eps=0.001$.
# >
# >3) Modifier le programme `dicho.m` pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près.

# %% [markdown]
# ### Correction exercice 2

# %% [markdown]
# ## **1)**
# *Dessiner la courbe de  𝑓  dans l'intervalle  [−2;2] , puis trouver des intervalles convenables pour appliquer la méthode de >bisection.*

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# # Daprés le graph de $f$ il existe 3 solutions :
# - $\alpha_1 \in ]-2;-1.5[$
# - $\alpha_2 \in ]-1.5;-0.5[$
# - $\alpha_3 \in ]1.5;2[$

# %% [markdown]
# ## **2)**
# *Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation  𝑓(𝑥)=0  avec  𝑒𝑝𝑠=0.001 .*

# %%
def dicho (f ,a ,b , eps ):

    g , d = min (a , b ) , max (a , b )
    valg , vald = f ( g ) , f ( d )
    n = 0
    while d - g > eps :
        n += 1
        m = ( g + d )/2
        valm = f ( m )
        if valg * valm < 0 :
            d = m
            vald = valm
        else :
            g = m
            valg = valm
    print (" nombre d'itérations nécessaires :", n )
    return ( g + d )/2

# %%
dicho( f, -2 , 2 , 0.001)
# Out:
#  nombre d'itérations nécessaires : 12
# 0.56689453125

# %%
x3=dicho(f,-2,-1.5,10)
print(x3)
# Out:
#  nombre d'itérations nécessaires : 0
# -1.75

# %%
dicho ( f,-2,-1.5 , 0.0001)
# Out:
#  nombre d'itérations nécessaires : 13
# -1.500030517578125

# %%
inter=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for j in inter:
    print(dicho(f,j[0],j[1],0.001))
# Out:
#  nombre d'itérations nécessaires : 9
# -1.73193359375
#  nombre d'itérations nécessaires : 10
# -0.50048828125
#  nombre d'itérations nécessaires : 9
# 1.73193359375

# %%
dicho ( f, -2 , -1.5 , 0.00001)
# Out:
#  nombre d'itérations nécessaires : 16
# -1.5000038146972656

# %% [markdown]
# **3)**

# %% [markdown]
# *Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à  𝑒𝑝𝑠  près.*

# %%
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# # EXERCICE 3:
# >On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
# >
# >2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
# >
# >a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
# >
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >
# >3) Ecrire puis appliquer  une fonction Matlab que l'on appellera  `pointfixe.m` aux trois schémas précédents en prenant >`x0=1.5;eps=0.001`.
# >
# >4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?
# >

# %% [markdown]
# # Correction exercice 3
# **1)**
#
# *Dessiner la courbe de  𝑓  dans l'intervalle  [1;2] , puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).*

# %%
import numpy as np 
import matplotlib.pyplot as plt
f=lambda x:x**3+4*x**2-10
t=np.linspace(1,2,100)
plt.xlabel('X')
plt.ylabel('F(x)')
plt.title('Courbe de f dans [1,2]')
plt.plot(t,f(t),'b')
plt.grid(True)

# %%
x=np.linspace ( 1 ,2, 100)
plt.subplot(2,2,1)
plt.plot(x,f(x),'r')
plt.grid(True)
####################
x=np.linspace ( 1.2 ,1.4, 100)
plt.subplot(2,2,2)
plt.plot(x,f(x),'r')
plt.grid(True)
###################
x=np.linspace ( 1.35 ,1.4, 100)
plt.subplot(2,2,3)
plt.plot(x,f(x),'r')
plt.grid(True)
###################
x=np.linspace ( 1.365 ,1.366, 100)
plt.subplot(2,2,4)
plt.plot(x,f(x),'r')
plt.grid(True)

# %% [markdown]
# **2)**
#
# *Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:*
#
# *a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.*

# %% [markdown]
# ### *Calcul symbolique de la dérivée*

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# #### *Que pouvez vous conclure à propos des convergences de g1*

# %% [markdown]
# D'aprés le théoréme de convergence locale du point fixe on a la dérivé<1 donc on peut dire que la fonction g1 converge localement

# %% [markdown]
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# #### *Que pouvez vous conclure à propos des convergences de g2*

# %% [markdown]
#  d'aprés le théoréme de convergence de la méthode du point fixe on a:
# Si |g
# 0
# (α)| < 1, alors la méthode de point fixe converge localement
#
# Donc la fonction g2 converge

# %% [markdown]
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# #### *Que pouvez vous conclure à propos des convergences de g3*

# %% [markdown]
# on a :
#  Si |g
# 0
# (l)| > 1, la m´ethode de point fixe (la suite (xn) d´efinie par xn+1 = g(xn)) diverge pour
# tout choix de x0 6= α et x0 ∈ [a, b].

# %% [markdown]
# Donc la fonction g3 diverge

# %% [markdown]
# **3)**
#
# Ecrire puis appliquer une fonction Matlab que l'on appellera pointfixe.m aux trois schémas précédents en prenant >x0=1.5;eps=0.001.

# %%
import numpy as np
f=lambda x:x**3+4*x**2-10
g1=lambda x: 1/2*sqrt(10-x**3)
g2=lambda x:sqrt(10./(x+4))
g3=lambda x:x-x**3-4*x**2+10
def pointfixe(g, x0, eps, nmax):
    zero= x0
    for k in range(nmax):
        x = zero    
        zero = g(x)    
        erreur = abs(zero - x)
        print(zero)
        if erreur < eps:
            return zero , k
       
    print('pas de convergence avec le nombre d\'iteration indique')

# %%
pointfixe(g1,1.5,0.001,50)
# Out:
# 1.28695376762338
# 1.40254080353958
# 1.34545837402329
# 1.37517025281604
# 1.36009419276173
# 1.36784696759213
# 1.36388700388402
# 1.36591673339004
# 1.36487821719368
# 1.36541006116996
# (1.36541006116996, 9)

# %%
pointfixe(g2,1.5,0.001,50)
# Out:
# 1.34839972492648
# 1.36737637199128
# 1.36495701540249
# 1.36526474811344
# (1.36526474811344, 3)

# %%
pointfixe(g3,1.5,0.001,50)
# Out:
# -0.875
# 6.732421875
# -469.72001200169325
# 102754555.18738511
# -1.0849338705317464e+24
# 1.277055591444378e+72
# -2.082712908581025e+216
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-130-bcc18db72cab> in <module>
# ----> 1 pointfixe(g3,1.5,0.001,50)
#
# <ipython-input-125-026f7ef85a00> in pointfixe(g, x0, eps, nmax)
#       8     for k in range(nmax):
#       9         x = zero
# ---> 10         zero = g(x)
#      11         erreur = abs(zero - x)
#      12         print(zero)
#
# <ipython-input-125-026f7ef85a00> in <lambda>(x)
#       3 g1=lambda x: 1/2*sqrt(10-x**3)
#       4 g2=lambda x:sqrt(10./(x+4))
# ----> 5 g3=lambda x:x-x**3-4*x**2+10
#       6 def pointfixe(g, x0, eps, nmax):
#       7     zero= x0
#
# OverflowError: (34, 'Result too large')

# %% [markdown]
# ### quelle est la fonction qui donne la convergence la plus rapide ??

# %% [markdown]
# Le nombre d itérations pour g2 est le plus petit (égal à 3) donc la fonction qui donne la convergence la plus rapide

# %% [markdown]
# Donner le nombre d'itération pour chaque méthode convergent e

# %% [markdown]
# + $g_2$ donne le resultat en itérations = 3
# + $g_1$ donne le resultat en itérations = 9
#
# **+ $g_3$ est - elle convergente?**
#
# Non g3 est divergente, en fait elle donne un grand nombre d'itérations

# %% [markdown]
# # EXERCICE 4:
# >1) On considère la fonction $f(x)=e^{-x}-x$. Ecrire puis appliquer  une fonction Matlab que l'on appellera `newton.m` à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ .
# >
# >2) Montrer que l'équation $f(x)=0$ admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de $x0=1$.

# %% [markdown]
# # Correction exercice 4
# **1)**

# %% [markdown]
# *On considère la fonction  𝑓(𝑥)=𝑒−𝑥−𝑥 . Ecrire puis appliquer une fonction Matlab que l'on appellera newton.m à la >fonction  𝑓 , en prenant  𝑥0=0 ,  𝑒𝑝𝑠=0.001  .*

# %%
def newton(a, eps):
    x1= a
    x2= x1-f(x1)/f_prime(x1)
    while abs(x1 - x2) > eps:
        x1 = x2
        x2 = x1 - f(x1) / f_prime(x1)
    return  x2

# %%
import math
f= lambda x:math.exp(-x)-x
f_prime =lambda x:-math.exp(-x)-1

# %%
sol = newton(0, 0.001)
print(sol)
# Out:
# 0.5671431650348622

# %% [markdown]
# **2)**
#
# Montrer que l'équation  𝑓(𝑥)=0  admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de  𝑥0=1 .

# %%
sol=newton(1,0.001)
print(sol)
# Out:
# 0.567143285989123

# %% [markdown]
# Donc  l'équation 𝑓(𝑥)=0 admet une solution unique
